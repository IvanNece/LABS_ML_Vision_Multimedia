# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IvanNece/LABS_ML_Vision_Multimedia/blob/main/Lab02_HyperparameterSelection/Hyper-parameter-tuning.ipynb)

# %% [markdown]
# # Lab 2 — Hyper-parameter tuning on Fashion-MNIST (PyTorch)
